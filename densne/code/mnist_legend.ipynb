# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
K = 10
cmap = cm.viridis(np.linspace(0,1,K))

# %%
x = np.linspace(0, 10, K)
y = np.linspace(0, 10, K)

plt.scatter(x, y, c = cmap)
plt.show()
